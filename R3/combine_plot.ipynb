# %%
import numpy as np
import matplotlib.image as img
import matplotlib.pyplot as plt
import PIL
from PIL import image

# %%
events = [23789294, 23891929, 40363753, 40750224, 40750656, 60073678, 65395717, 65511496, 67522832, 67522901, 69509443, 71665813, 71784400, 71784833, 71785167, 73726599, 83984528, 84081108, 92773515, 92844954, 135577833, 151677988, 153859596, 154910364, 154913824, 155079679, 163181014, 163362088, 163534005, 166812476, 171681248, 171855709, 175004577, 175929272, 176060009, 180666196, 180667327, 188553320, 194488374, 194488393, 194488454, 195132396, 200973875, 203798724, 203935225]
events = np.array(events)
events_I = [139459007, 144520399, 154779432, 176156139, 188760049, 188760957, 198142107, 157779605, 162981697, 163181404, 165238765, 175084048, 175930797]
events_I = np.array(events_I)

# %%
# fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(15, 12))

# for e, ax in zip(events,axs.ravel()):
#     path = "/Users/ketansand/Notebooks/Final_plots/waterfall_bb/{}_wfall_bb_fin.jpeg".format(e)
#     img1 = img.imread(path)
#     ax.axis('off')
#     ax.imshow(img1)
    
plt.figure(figsize=(15, 12))
plt.subplots_adjust(hspace=0,wspace=0)

# loop through the length of tickers and keep track of index
for i in range(len(events)):
    # add a new subplot iteratively
    ax = plt.subplot(9, 5, i + 1)
    path = "/Users/ketansand/Notebooks/Final_plots/waterfall_bb/{}_wfall_bb_fin.jpeg".format(events[i])
    img1 = img.imread(path)
    ax.axis('off')
    ax.imshow(img1)


plt.show()
