# %%
import numpy as np

# %%
file = np.load('/Users/ketansand/Downloads/fitburst_spectral_lookup.npz')
for k in file.items():
    print(k)
# Out:
# ('spectral_index', array([[  1.01575168,   1.01576966,   1.01578844, ...,   1.01702536,
#           1.01702224,   1.01700308],
#        [ 25.86026069,  20.09111461,  16.1312236 , ...,   1.49337773,
#           1.47738445,   1.46219185],
#        [ 51.45605993,  39.68797749,  31.62846739, ...,   1.97613907,
#           1.94389708,   1.9132901 ],
#        ...,
#        [  9.29153926,  10.24643058,  11.30202556, ...,  35.32481179,
#          35.54905931,  34.62213769],
#        [ -5.59511246,  -2.37167187,   0.5010029 , ...,  34.39206773,
#          34.63687815,  34.87515372],
#        [-28.73511015, -20.65946812, -14.34691453, ...,  33.44772752,
#          33.71387765,  33.97263755]]))
# ('spectral_running', array([[-639.35046173, -494.96539803, -395.41352502, ...,  -16.77105189,
#          -16.2983491 ,  -15.84866711],
#        [-641.86122959, -496.64882517, -396.6015065 , ...,  -16.7835212 ,
#          -16.31032515,  -15.86014671],
# ...

# %%
x = 100
dx = 7.071068
y = 10.1
dy = 0.424264

err = np.sqrt((dx/x)**2 + (dy/y)**2) * (x/y)
print(err)
# Out:
# 0.8143245401947317
